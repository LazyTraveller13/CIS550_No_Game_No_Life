# %%
import pandas
a = pandas.read_csv('Games.csv')

# %%
a[['G']].std()
# Out:
# metacritic    11.292029
# dtype: float64

# %%
a
# Out:
#             id                                     slug  \
# 0            1                           dgeneration-hd
# 1           10                                  g-prime
# 2          100                             land-sliders
# 3         1000                               pixel-gear
# 4        10000                           gods-and-idols
# 5       100000                             plague-venue
# 6       100001                     the-moon-sliver-itch
# 7       100002                               red-entity
# 8       100003                                  rollman
# 9       100004                            hippiesvscops
# 10      100005              they-came-through-the-floor
# 11      100006                     fading-light-descent
# 12      100007                     the-book-ritual-beta
# 13      100009             corner-of-the-club-simulator
# 14       10001             serious-sam-fusion-2017-beta
# 15      100010             intelligence-the-314th-clash
# ...

# %%
b = pandas.read_csv('game_sales_with_image.csv')

# %%
len(b['Platform'].unique())
# Out:
# 74
