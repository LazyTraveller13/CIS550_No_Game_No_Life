# %%
# import required libraries
import pandas as pd
import numpy as np

# %%
Game_origin = pd.read_csv('./Games.csv')
Game_sales_origin = pd.read_csv('../game sales with image from vg/game_sales_with_image.csv')
Game_reviews_origin = pd.read_csv('../game reviews from vandal/game_reviews.csv')

# %%
Game_origin
# Out:
#             id                        name release_date  \
# 0            1             D/Generation HD   2015-10-23
# 1            2            Extreme Exorcism    2015-9-23
# 2            3          Toto Temple Deluxe    2015-9-29
# 3            4                    Penarium    2015-9-22
# 4            5                  Standpoint     2015-3-5
# ...        ...                         ...          ...
# 310509  388930                    Futurism   2019-10-31
# 310510  388931  Space Invaders 3D (Flozer)   2019-10-31
# 310511  388932           Sinking Ship Chef   2019-10-31
# 310512  388933             Messy Mechanics   2019-10-31
# 310513  388935                 ELCHRONICLE    2019-4-26
#
#                                                 developer
# 0        West Coast Software, West Coast Software Limited
# 1                                       Golden Ruby Games
# 2       Juicy Beast, Juicy Beast Studio, JUICY BEAST S...
# 3                       Self Made Miracle, Team17 Digital
# 4                                      Unruly Attractions
# ...                                                   ...
# 310509                             Monoux College - Games
# 310510                                             Flozer
# 310511                                           BiggBenn
# 310512                                       Dwight Davis
# 310513                                       Cravemob Co.
#
# [310514 rows x 4 columns]

# %%
# filter the release_date
Game_origin.filter(regex='....-*-*', axis=0)
# Out:
#             id                          name release_date  \
# 1000      1061                       Gunjack     2016-4-5
# 1001      1063              FINAL FANTASY VI     1994-4-2
# 1002      1064  Hatsune Miku: VR Future Live   2016-10-13
# 1003      1065                    Headmaster   2016-10-13
# 1004      1066                Puppet War:FPS    2010-6-10
# ...        ...                           ...          ...
# 310509  388930                      Futurism   2019-10-31
# 310510  388931    Space Invaders 3D (Flozer)   2019-10-31
# 310511  388932             Sinking Ship Chef   2019-10-31
# 310512  388933               Messy Mechanics   2019-10-31
# 310513  388935                   ELCHRONICLE    2019-4-26
#
#                                                 developer
# 1000                                       CCP, CCP Games
# 1001    Sony Interactive Entertainment, Square Enix, S...
# 1002                                                 SEGA
# 1003      Frame Interactive Studio LLC, Frame Interactive
# 1004                                             Twindigo
# ...                                                   ...
# 310509                             Monoux College - Games
# 310510                                             Flozer
# 310511                                           BiggBenn
# 310512                                       Dwight Davis
# 310513                                       Cravemob Co.
#
# [309514 rows x 4 columns]
